# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# YOUR CODE HERE
# set the filepath and load in a shapefile


data = pd.read_csv("Hospice_Compare_-_Provider_CAHPS_Hospice_Survey_Data.csv", low_memory=False)
# print(data.head())
df = pd.DataFrame(data)



state_score = df.loc [:, ['State','Score']]
#state_city_score = df.loc[:, 'State']
#print(state_score)

# values = state_score.Score.value_counts()
# print(state_score)
is_TX =  state_score['State']=='TX'
#print(is_TX)


# # # filter rows for TX using  the boolean variable
filter_TX = state_score[is_TX]

#print(filter_TX.shape)
# filter_TX.mean()
# filter_TX.describe()
#filter_TX.Score.value_counts()

# columnSeriesObj = []
# for column in filter_TX[['State', 'Score']]:
#     print(filter_TX[Score])


#    # Select column contents by column name using [] operator
#    columnSeriesObj = filter_TX['Score']
# print(columnSeriesObj)
# We have successfully filtered pandas dataframe based on values of a column. Here, all the rows with State equal TX.



# state_score1 = state_score.set_index('State')
# state_score.describe()

# %%
# Iterate over the sequence of column names
for column in state_score:
       # Select column contents by column name using [] operator
    Texas = state_score['State'] == 'TX'
    
print(Texas)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 114018    False
# 114019    False
# 114020    False
# 114021    False
# 114022    False
# 114023    False
# 114024    False
# 114025    False
# 114026    False
# 114027    False
# 114028    False
# 114029    False
# 114030    False
# 114031    False
# 114032    False
# 114033    False
# 114034    False
# 114035    False
# 114036    False
# 114037    False
# 114038    False
# 114039    False
# 114040    False
# 114041    False
# 114042    False
# 114043    False
# 114044    False
# 114045    False
# 114046    False
# 114047    False
# Name: State, Length: 114048, dtype: bool

# %%
import statistics
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# Create an empty list 

nat_row_list =[] 
  
# Iterate over each row 
for index, rows in state_score.iterrows(): 
    # Create list for the current row 
    my_list =[rows.Score] 
      
    # append the list to the final list 
    nat_row_list.append(my_list) 
  
# Print the list 
clean_row_list = []
for i in nat_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            clean_row_list.append(j)
new_list = list(map(int, clean_row_list)) 

NAT_new_list = list(map(int, clean_row_list))  
NAT_lower_values= []
for k in NAT_new_list:
    if k <50:
        NAT_lower_values.append(k)
    else:
        pass
NAT_mean_lower = statistics.mean(NAT_lower_values)

NAT_upper_values = []
for l in NAT_new_list:
    if l >50:
        NAT_upper_values.append(l)
    else:
        pass
NAT_mean_upper = statistics.mean(NAT_upper_values)
print(NAT_mean_upper)
NAT_sd_lower = statistics.stdev(NAT_lower_values)
print(NAT_mean_lower)

NAT_sd_upper = statistics.stdev(NAT_upper_values)


print(statistics.mean(NAT_new_list))
print(statistics.median(NAT_new_list))
num_bins = 100
n, bins, patches = plt.hist(NAT_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("National Scores")
ax.set_xlabel('Score')
ax.set_ylabel('Count')
plt.show()
#print(filter_ND.shape)

frame = pd.DataFrame(NAT_new_list)

# Sample from two different normal distributions
means = NAT_mean_lower, NAT_mean_upper
stdevs = NAT_sd_lower, NAT_sd_upper
frame.agg(['min', 'max', 'mean', 'std']).round(decimals=2)

fig, ax = plt.subplots()
frame.plot.kde(ax=ax, legend=False, title='Kernel Density')
frame.plot.hist(density=True, ax=ax, facecolor = 'blue')
ax.set_ylabel('Probability')
ax.set_xlabel('Score')
ax.grid(axis='y')
ax.set_facecolor('#d8dcd8')
# Out:
# 81.79656630144078
# 9.736688498219005
# 34.783586452976714
# 14

# %%
high mean = 81.79656630144078
low mean = 9.736688498219005
34.783586452976714
mode = 14

# %%
TX_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_TX.iterrows(): 
    # Create list for the current row 
    TX_my_list =[rows.Score] 
      
    # append the list to the final list 
    TX_row_list.append(TX_my_list) 
  
# Print the list 
TX_clean_row_list = []
for i in TX_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            TX_clean_row_list.append(j)
TX_new_list = list(map(int, TX_clean_row_list))  
TX_lower_values= []
for k in TX_new_list:
    if k <50:
        TX_lower_values.append(k)
    else:
        pass
print(statistics.mean(NJ_lower_values))

TX_upper_values = []
for l in TX_new_list:
    if l >50:
        TX_upper_values.append(l)
    else:
        pass
print(statistics.mean(TX_upper_values))

print(statistics.mean(TX_new_list))
print(statistics.median(TX_new_list))
num_bins = 150
n, bins, patches = plt.hist(TX_new_list, num_bins, facecolor='blue', alpha=0.8)
# plt.title("Texas Scores")
# plt.show()
print(len(TX_new_list))

# %%
is_MD =  state_score['State']=='MD'
#print(is_MD)


# # filter rows for TX using  the boolean variable
filter_MD = state_score[is_MD]

MD_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_MD.iterrows(): 
    # Create list for the current row 
    MD_my_list =[rows.Score] 
      
    # append the list to the final list 
    MD_row_list.append(MD_my_list) 
  
# Print the list 
MD_clean_row_list = []
for i in MD_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            MD_clean_row_list.append(j)
MD_new_list = list(map(int, MD_clean_row_list)) 

MD_lower_values= []
for k in MD_new_list:
    if k <50:
        MD_lower_values.append(k)
    else:
        pass
print(statistics.mean(MD_lower_values))

MD_upper_values = []
for l in MD_new_list:
    if l >50:
        MD_upper_values.append(l)
    else:
        pass
print(statistics.mean(MD_upper_values))


print(statistics.mean(MD_new_list))
print(statistics.median(MD_new_list))
print(len((MD_new_list)))
num_bins = 100
n, bins, patches = plt.hist(MD_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Maryland Scores")
plt.show()
# #print(filter_MD.shape)
# Out:
# 9.466666666666667
# 82.25
# 34.78260869565217
# 14
# 529

# %%
is_NJ =  state_score['State']=='NJ'
#print(is_NJ)


# # filter rows for TX using  the boolean variable
filter_NJ = state_score[is_NJ]

NJ_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_NJ.iterrows(): 
    # Create list for the current row 
    NJ_my_list =[rows.Score] 
      
    # append the list to the final list 
    NJ_row_list.append(NJ_my_list) 
  
# Print the list 
NJ_clean_row_list = []
for i in NJ_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            NJ_clean_row_list.append(j)
NJ_new_list = list(map(int, NJ_clean_row_list))  

print(statistics.mean(NJ_new_list))
print(statistics.median(NJ_new_list))
num_bins = 100
n, bins, patches = plt.hist(NJ_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("New Jersey Scores")
plt.show()
#print(filter_NJ.shape)

# %%
is_NJ =  state_score['State']=='NJ'

#print(is_NJ)


# # filter rows for TX using  the boolean variable
filter_NJ = state_score[is_NJ]

NJ_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_NJ.iterrows(): 
    # Create list for the current row 
    NJ_my_list =[rows.Score] 
      
    # append the list to the final list 
    NJ_row_list.append(NJ_my_list) 
  
# Print the list 
NJ_clean_row_list = []
for i in NJ_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            NJ_clean_row_list.append(j)
NJ_new_list = list(map(int, NJ_clean_row_list)) 

NJ_lower_values= []
for k in NJ_new_list:
    if k <50:
        NJ_lower_values.append(k)
    else:
        pass
print(statistics.mean(NJ_lower_values))

NJ_upper_values = []
for l in NJ_new_list:
    if l >50:
        NJ_upper_values.append(l)
    else:
        pass
print(statistics.mean(NJ_upper_values))

print(statistics.mean(NJ_new_list))
print(statistics.median(NJ_new_list))
print(len(NJ_new_list))
num_bins = 100
n, bins, patches = plt.hist(NJ_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("New Jersey Scores")
plt.show()
# #print(filter_NJ.shape)
# Out:
# 10.295833333333333
# 80.6953125
# 34.78260869565217
# 14.0
# 1104

# %%
is_HI =  state_score['State']=='HI'
#print(is_HI)


# # filter rows for TX using  the boolean variable
filter_HI = state_score[is_HI]

HI_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_HI.iterrows(): 
    # Create list for the current row 
    HI_my_list =[rows.Score] 
      
    # append the list to the final list 
    HI_row_list.append(HI_my_list) 
  
# Print the list 
HI_clean_row_list = []
for i in HI_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            HI_clean_row_list.append(j)
HI_new_list = list(map(int, HI_clean_row_list))

HI_lower_values= []
for k in HI_new_list:
    if k <50:
        HI_lower_values.append(k)
    else:
        pass
print(statistics.mean(HI_lower_values))

HI_upper_values = []
for l in HI_new_list:
    if l >50:
        HI_upper_values.append(l)
    else:
        pass
print(statistics.mean(HI_upper_values))

print(statistics.mean(HI_new_list))
print(statistics.median(HI_new_list))
num_bins = 100
n, bins, patches = plt.hist(HI_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Hawaii Scores")
plt.show()
#print(filter_HI.shape)
# Out:
# 9.088888888888889
# 82.95833333333333
# 34.78260869565217
# 12

# %%
is_MA =  state_score['State']=='MA'
#print(is_MA)


# # filter rows for TX using  the boolean variable
filter_MA = state_score[is_MA]

MA_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_MA.iterrows(): 
    # Create list for the current row 
    MA_my_list =[rows.Score] 
      
    # append the list to the final list 
    MA_row_list.append(MA_my_list) 
  
# Print the list 
MA_clean_row_list = []
for i in MA_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            MA_clean_row_list.append(j)
MA_new_list = list(map(int, MA_clean_row_list))  

lower_values= []
MA_lower_values= []
for k in MA_new_list:
    if k <50:
        MA_lower_values.append(k)
    else:
        pass
print(statistics.mean(MA_lower_values))

MA_upper_values = []
for l in MA_new_list:
    if l >50:
        MA_upper_values.append(l)
    else:
        pass
print(statistics.mean(MA_upper_values))
print(statistics.mean(MA_new_list))
print(statistics.median(MA_new_list))
num_bins = 100
n, bins, patches = plt.hist(MA_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Massachusetts Scores")
plt.show()
#print(filter_MA.shape)
# Out:
# 9.486916951080774
# 82.21961620469084
# 34.79228486646884
# 13.0

# %%
is_CT =  state_score['State']=='CT'
#print(is_CT)


# # filter rows for TX using  the boolean variable
filter_CT = state_score[is_CT]

CT_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_CT.iterrows(): 
    # Create list for the current row 
    CT_my_list =[rows.Score] 
      
    # append the list to the final list 
    CT_row_list.append(CT_my_list) 
  
# Print the list 
CT_clean_row_list = []
for i in CT_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            CT_clean_row_list.append(j)
CT_new_list = list(map(int, CT_clean_row_list))  

lower_values= []
for k in CT_new_list:
    if k <50:
        lower_values.append(k)
    else:
        pass
print(statistics.mean(lower_values))

upper_values = []
for l in CT_new_list:
    if l > 50:
        upper_values.append(l)
    else:
        pass
print(statistics.mean(upper_values))



print(statistics.mean(CT_new_list))
print(statistics.median(CT_new_list))
num_bins = 100
n, bins, patches = plt.hist(CT_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Connecticut Scores")
plt.show()
#print(filter_CT.shape)
# Out:
# 9.866666666666667
# 81.5
# 34.78260869565217
# 14

# %%
is_WV =  state_score['State']=='WV'
#print(is_WV)


# # filter rows for TX using  the boolean variable
filter_WV = state_score[is_WV]

WV_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_WV.iterrows(): 
    # Create list for the current row 
    WV_my_list =[rows.Score] 
      
    # append the list to the final list 
    WV_row_list.append(WV_my_list) 
  
# Print the list 
WV_clean_row_list = []
for i in WV_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            WV_clean_row_list.append(j)
WV_new_list = list(map(int, WV_clean_row_list))  

lower_values= []
for k in WV_new_list:
    if k <50:
        lower_values.append(k)
    else:
        pass
print(statistics.mean(lower_values))

upper_values = []
for l in WV_new_list:
    if l > 50:
        upper_values.append(l)
    else:
        pass
print(statistics.mean(upper_values))


print(statistics.mean(WV_new_list))
print(statistics.median(WV_new_list))
num_bins = 100
n, bins, patches = plt.hist(WV_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("West Virginia Scores")
plt.show()
#print(filter_WV.shape)
# Out:
# 7.859649122807017
# 85.26315789473684
# 34.78260869565217
# 11

# %%
is_MS =  state_score['State']=='MS'
#print(is_MS)


# # filter rows for TX using  the boolean variable
filter_MS = state_score[is_MS]

MS_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_MS.iterrows(): 
    # Create list for the current row 
    MS_my_list =[rows.Score] 
      
    # append the list to the final list 
    MS_row_list.append(MS_my_list) 
  
# Print the list 
MS_clean_row_list = []
for i in MS_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            MS_clean_row_list.append(j)
MS_new_list = list(map(int, MS_clean_row_list)) 

lower_values= []
for k in MS_new_list:
    if k <50:
        lower_values.append(k)
    else:
        pass
print(statistics.mean(lower_values))

upper_values = []
for l in MS_new_list:
    if l > 50:
        upper_values.append(l)
    else:
        pass
print(statistics.mean(upper_values))

print(statistics.mean(MS_new_list))
print(statistics.median(MS_new_list))
num_bins = 100
n, bins, patches = plt.hist(MS_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Mississippi Scores")
plt.show()
#print(filter_MS.shape)
# Out:
# 8.522388059701493
# 84.02797202797203
# 34.79318734793188
# 12

# %%
is_AR =  state_score['State']=='AR'
#print(is_AR)


# # filter rows for TX using  the boolean variable
filter_AR = state_score[is_AR]

AR_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_AR.iterrows(): 
    # Create list for the current row 
    AR_my_list =[rows.Score] 
      
    # append the list to the final list 
    AR_row_list.append(AR_my_list) 
  
# Print the list 
AR_clean_row_list = []
for i in AR_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            AR_clean_row_list.append(j)
AR_new_list = list(map(int, AR_clean_row_list))  

AR_lower_values= []
for k in AR_new_list:
    if k <50:
        AR_lower_values.append(k)
    else:
        pass
print(statistics.mean(AR_lower_values))

AR_upper_values = []
for l in AR_new_list:
    if l >50:
        AR_upper_values.append(l)
    else:
        pass
print(statistics.mean(AR_upper_values))



print(statistics.mean(AR_new_list))
print(statistics.median(AR_new_list))
num_bins = 100
n, bins, patches = plt.hist(AR_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Arkansas Scores")
plt.show()
#print(filter_AR.shape)
# Out:
# 8.726126126126125
# 83.63851351351352
# 34.78260869565217
# 12

# %%
is_LA =  state_score['State']=='LA'
#print(is_LA)


# # filter rows for TX using  the boolean variable
filter_LA = state_score[is_LA]

LA_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_LA.iterrows(): 
    # Create list for the current row 
    LA_my_list =[rows.Score] 
      
    # append the list to the final list 
    LA_row_list.append(LA_my_list) 
  
# Print the list 
LA_clean_row_list = []
for i in LA_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            LA_clean_row_list.append(j)
LA_new_list = list(map(int, LA_clean_row_list))  

lower_values= []
for k in LA_new_list:
    if k <50:
        lower_values.append(k)
    else:
        pass
print(statistics.mean(lower_values))

upper_values = []
for l in LA_new_list:
    if l >50:
        upper_values.append(l)
    else:
        pass
print(statistics.mean(upper_values))
        
print(statistics.mean(LA_new_list))
print(statistics.median(LA_new_list))
num_bins = 100
n, bins, patches = plt.hist(LA_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("Louisiana Scores")
plt.show()
#print(filter_LA.shape)
# Out:
# 8.19645390070922
# 84.63164893617021
# 34.78260869565217
# 11.0

# %%
is_NM =  state_score['State']=='NM'
#print(is_NM)


# # filter rows for TX using  the boolean variable
filter_NM = state_score[is_NM]

NM_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_NM.iterrows(): 
    # Create list for the current row 
    NM_my_list =[rows.Score] 
      
    # append the list to the final list 
    NM_row_list.append(NM_my_list) 
  
# Print the list 
NM_clean_row_list = []
for i in NM_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            NM_clean_row_list.append(j)
NM_new_list = list(map(int, NM_clean_row_list))  

NM_lower_values= []
for k in NM_new_list:
    if k <50:
        NM_lower_values.append(k)
    else:
        pass
print(statistics.mean(NM_lower_values))

NM_upper_values = []
for l in NM_new_list:
    if l >50:
        NM_upper_values.append(l)
    else:
        pass
print(statistics.mean(NM_upper_values))

print(statistics.mean(NM_new_list))
print(statistics.median(NM_new_list))
num_bins = 100
n, bins, patches = plt.hist(NM_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("New Mexico Scores")
plt.show()
#print(filter_NM.shape)
# Out:
# 10.455555555555556
# 80.39583333333333
# 34.78260869565217
# 15.0

# %%
is_UT =  state_score['State']=='UT'
#print(is_UT)


# # filter rows for TX using  the boolean variable
filter_UT = state_score[is_UT]

UT_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_UT.iterrows(): 
    # Create list for the current row 
    UT_my_list =[rows.Score] 
      
    # append the list to the final list 
    UT_row_list.append(UT_my_list) 
  
# Print the list 
UT_clean_row_list = []
for i in UT_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            UT_clean_row_list.append(j)
UT_new_list = list(map(int, UT_clean_row_list)) 

UT_lower_values= []
for k in UT_new_list:
    if k <50:
        UT_lower_values.append(k)
    else:
        pass
print(statistics.mean(UT_lower_values))

UT_upper_values = []
for l in UT_new_list:
    if l >50:
        UT_upper_values.append(l)
    else:
        pass
print(statistics.mean(UT_upper_values))

print(statistics.mean(UT_new_list))
print(statistics.median(UT_new_list))
num_bins = 100
n, bins, patches = plt.hist(UT_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("UTAH Scores")
plt.show()
#print(filter_UT.shape)

# %%
is_ND =  state_score['State']=='ND'
#print(is_ND)


# # filter rows for TX using  the boolean variable
filter_ND = state_score[is_ND]

ND_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_ND.iterrows(): 
    # Create list for the current row 
    ND_my_list =[rows.Score] 
      
    # append the list to the final list 
    ND_row_list.append(ND_my_list) 
  
# Print the list 
ND_clean_row_list = []
for i in ND_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            ND_clean_row_list.append(j)
ND_new_list = list(map(int, ND_clean_row_list)) 

ND_lower_values= []
for k in ND_new_list:
    if k <50:
        ND_lower_values.append(k)
    else:
        pass
print(statistics.mean(ND_lower_values))

sd1 = statistics.stdev(ND_lower_values)
print(sd1)


ND_upper_values = []
for l in ND_new_list:
    if l >50:
        ND_upper_values.append(l)
    else:
        pass
print(statistics.mean(ND_upper_values))

sd2 = statistics.stdev(ND_upper_values)
print(sd2)

print(statistics.mean(ND_new_list))
print(statistics.median(ND_new_list))
num_bins = 100
n, bins, patches = plt.hist(ND_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("North Dakota Scores")
plt.show()
#print(filter_ND.shape)
frame = pd.DataFrame(ND_new_list)

# Sample from two different normal distributions
means = 8.73, 83.64
stdevs = 4.75, 8.73
frame.agg(['min', 'max', 'mean', 'std']).round(decimals=2)

fig, ax = plt.subplots()
frame.plot.kde(ax=ax, legend='scores', title='Kernel Density')
frame.plot.hist(density=True, ax=ax, facecolor = 'blue')
ax.set_ylabel('Probability')
ax.set_xlabel('Score')
ax.grid(axis='y')
ax.set_facecolor('#d8dcd8')

# %%
is_CA =  state_score['State']=='CA'
#print(is_CA)


# # filter rows for TX using  the boolean variable
filter_CA = state_score[is_CA]

CA_row_list =[] 
  
# Iterate over each row 
for index, rows in filter_CA.iterrows(): 
    # Create list for the current row 
    CA_my_list =[rows.Score] 
      
    # append the list to the final list 
    CA_row_list.append(CA_my_list) 
  
# Print the list 
CA_clean_row_list = []
for i in CA_row_list:
    for j in i:
        if str(j)== 'Not Available' or str(j)=='Not Applicable' or str(j) == 'Not  Available':
            pass
        else:
            CA_clean_row_list.append(j)
CA_new_list = list(map(int, CA_clean_row_list)) 

CA_lower_values= []
for k in CA_new_list:
    if k <50:
        CA_lower_values.append(k)
    else:
        pass
low_CA = statistics.mean(CA_lower_values)

CA_upper_values = []
for l in CA_new_list:
    if l >50:
        CA_upper_values.append(l)
    else:
        pass
high_CA = statistics.mean(CA_upper_values)

mean_CA = statistics.mean(CA_new_list)
median_CA = statistics.median(CA_new_list)
num_bins = 100
n, bins, patches = plt.hist(CA_new_list, num_bins, facecolor='blue', alpha=0.8)
plt.title("California Scores")
plt.show()
#print(filter_CA.shape)

# %%
plt.bar([0.25, 1.25, 2.25, 3.25], NAT_mean_lower, label="Nat", width=.5)
plt.bar([.75, 1.75, 2.75, 3.75], low_CA, label="Cali", color='r', width=.5)

plt.legend()
plt.xlabel('Range')
plt.ylabel('Marks')
plt.title('Comparison')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
states = ['Fed. Pov. Level','West Virginia(50)','Mississippi(49)','Arkansas(48)','Louisiana(47)','New Mexico(46)', 'National Avg', 'Connecticut(5)', 'Massachusetts(4)', 'Hawaii(3)', 'New Jersey(2)', 'Maryland(1)' ]
income = ['$25,750','$43,469','$43,529','$45,869','$46,145','$46,744', '$61,372', '$74,168','$77,385','$77,765', '$80,088','$80,776']


    # this is for plotting purpose
def plot_bar_x():
    index = np.arange(len(states))
    plt.bar(index, income)
    plt.xlabel('States', fontsize=5)
    plt.ylabel('Income', fontsize=5)
    plt.xticks(index, states, fontsize=5, rotation=30)
    plt.title('Poorest States/Richest States')
    plt.show()
plot_bar_x()




# plt.bar(y_pos, x_pos, align='center', alpha=0.5)
# plt.xticks(y_pos, x_pos)
# plt.ylabel('Household Income')
# plt.title("Five 'Poorest' States")

# plt.show()

# %%
# Maryland = '$80,776'
# New Jersey = '$80,088'
# Hawaii = '$77,765'
# Massachusetts = '$$77,385'
# Connecticut = '$74,168'
import pandas as pd
high_score = [85.26, 84.03, 83.64, 84.63, 80.40]
low_score = [7.86, 8.52, 8.73, 8.20, 10.50]
index = ['West Virginia', 'Mississippi', 'Arkansas','Louisiana',
          'New Mexico']
df = pd.DataFrame({'high_score mean = 85.592': high_score,
                   'low_score mean = 8.762': low_score}, index=index)
ax = df.plot.bar(rot=0)
print(statistics.mean(high_score))
print(statistics.mean(low_score))
# Out:
# 83.592
# 8.762

# %%
high_score = [82.25, 80.70, 82.96, 82.22, 81.50]
low_score = [9.47, 10.30, 9.09, 9.49, 9.87]
index = ['Maryland', 'New Jersey', 'Hawaii','Mass',
          'Connecticut']
df = pd.DataFrame({'high_score mean = 81.926': high_score,
                   'low_score mean = 9.644': low_score}, index=index)
ax = df.plot.bar(rot=0)
print(statistics.mean(high_score))
print(statistics.mean(low_score))
# Out:
# 81.926
# 9.644

# %%
MD=(9.466666666666667
82.25
14)
NJ = (10.295833333333333
80.6953125
14.0)
HI =(9.088888888888889
82.95833333333333
12)
MA = (9.486916951080774
82.21961620469084
13.0)
CT = (9.866666666666667
81.5
14)
WV = (7.859649122807017
85.26315789473684
11
)
MS = (8.522388059701493
84.02797202797203
12)
AR = (8.726126126126125
83.63851351351352
12
)
LA = (8.19645390070922
84.63164893617021
11.0)
NM = (10.455555555555556
80.39583333333333
15.0)
